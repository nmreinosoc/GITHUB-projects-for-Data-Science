# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
plt.style.use("seaborn")

# %%
customers=pd.read_csv("Ecommerce Customers")

# %%
customers
# Out:
#                              Email  \
# 0        mstephenson@fernandez.com
# 1                hduke@hotmail.com
# 2                 pallen@yahoo.com
# 3          riverarebecca@gmail.com
# 4    mstephens@davidson-herman.com
# ..                             ...
# 495   lewisjessica@craig-evans.com
# 496            katrina56@gmail.com
# 497             dale88@hotmail.com
# 498            cwilson@hotmail.com
# 499      hannahwilson@davidson.com
#
#                                                Address            Avatar  \
# 0         835 Frank Tunnel\nWrightmouth, MI 82180-9605            Violet
# 1       4547 Archer Common\nDiazchester, CA 06566-8576         DarkGreen
# 2    24645 Valerie Unions Suite 582\nCobbborough, D...            Bisque
# 3     1414 David Throughway\nPort Jason, OH 22070-1220       SaddleBrown
# 4    14023 Rodriguez Passage\nPort Jacobville, PR 3...  MediumAquaMarine
# ..                                                 ...               ...
# ...

# %%
customers.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 500 entries, 0 to 499
# Data columns (total 8 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   Email                 500 non-null    object
#  1   Address               500 non-null    object
#  2   Avatar                500 non-null    object
#  3   Avg. Session Length   500 non-null    float64
#  4   Time on App           500 non-null    float64
#  5   Time on Website       500 non-null    float64
#  6   Length of Membership  500 non-null    float64
#  7   Yearly Amount Spent   500 non-null    float64
# dtypes: float64(5), object(3)
# memory usage: 31.4+ KB

# %%
customers.describe(include="all")
# Out:
#                     Email                                            Address  \
# count                 500                                                500
# unique                500                                                500
# top     nwagner@yahoo.com  07813 Randy Point\nLake Thomasberg, MO 06013-9920
# freq                    1                                                  1
# mean                  NaN                                                NaN
# std                   NaN                                                NaN
# min                   NaN                                                NaN
# 25%                   NaN                                                NaN
# 50%                   NaN                                                NaN
# 75%                   NaN                                                NaN
# max                   NaN                                                NaN
#
# ...

# %% [markdown]
# # Exploratory Data Analysis

# %%
sns.jointplot(data=customers,x="Time on Website",y="Yearly Amount Spent")

# %%
sns.jointplot(data=customers,x="Time on App",y="Yearly Amount Spent")

# %%
sns.jointplot(data=customers,x="Time on App",y="Length of Membership",kind="hex")

# %%
sns.pairplot(customers)

# %%
sns.lmplot(x="Length of Membership",y="Yearly Amount Spent",data=customers)

# %% [markdown]
# # Training and Testing Data

# %%
customers.columns
# Out:
# Index(['Email', 'Address', 'Avatar', 'Avg. Session Length', 'Time on App',
#        'Time on Website', 'Length of Membership', 'Yearly Amount Spent'],
#       dtype='object')

# %%
y=customers["Yearly Amount Spent"]
y
# Out:
# 0      587.951054
# 1      392.204933
# 2      487.547505
# 3      581.852344
# 4      599.406092
#           ...
# 495    573.847438
# 496    529.049004
# 497    551.620145
# 498    456.469510
# 499    497.778642
# Name: Yearly Amount Spent, Length: 500, dtype: float64

# %%
X=customers[['Avg. Session Length', 'Time on App',
             'Time on Website', 'Length of Membership']]
X
# Out:
#      Avg. Session Length  Time on App  Time on Website  Length of Membership
# 0              34.497268    12.655651        39.577668              4.082621
# 1              31.926272    11.109461        37.268959              2.664034
# 2              33.000915    11.330278        37.110597              4.104543
# 3              34.305557    13.717514        36.721283              3.120179
# 4              33.330673    12.795189        37.536653              4.446308
# ..                   ...          ...              ...                   ...
# 495            33.237660    13.566160        36.417985              3.746573
# 496            34.702529    11.695736        37.190268              3.576526
# 497            32.646777    11.499409        38.332576              4.958264
# 498            33.322501    12.391423        36.840086              2.336485
# 499            33.715981    12.418808        35.771016              2.735160
#
# [500 rows x 4 columns]

# %%
from sklearn.model_selection import train_test_split

# %%
train_test_split
# Out:
# <function sklearn.model_selection._split.train_test_split(*arrays, **options)>

# %%
X_train, x_test, y_train, y_test=train_test_split(X,y,test_size=0.3,random_state=101)

# %%
X_train.describe()
# Out:
#        Avg. Session Length  Time on App  Time on Website  Length of Membership
# count           350.000000   350.000000       350.000000            350.000000
# mean             33.029221    12.034586        37.081286              3.541640
# std               1.003787     0.951713         0.973205              0.983835
# min              30.492537     8.508152        34.476878              0.269901
# 25%              32.307026    11.438876        36.437212              2.910161
# 50%              33.077626    11.952549        37.081149              3.533975
# 75%              33.710028    12.674099        37.723881              4.130236
# max              35.860237    14.325655        39.672591              6.401229

# %%
x_test.describe()
# Out:
#        Avg. Session Length  Time on App  Time on Website  Length of Membership
# count           150.000000   150.000000       150.000000            150.000000
# mean             33.109130    12.094260        37.011818              3.514378
# std               0.966857     1.089179         1.094428              1.037527
# min              29.532429     9.824402        33.913847              0.789520
# 25%              32.413679    11.198340        36.227559              2.967027
# 50%              33.101258    12.082070        37.028879              3.534821
# 75%              33.725764    12.934809        37.649752              4.113391
# max              36.139662    15.126994        40.005182              6.922689

# %%
y_train.describe()
# Out:
# count    350.000000
# mean     498.723116
# std       76.639698
# min      266.086341
# 25%      445.401307
# 50%      497.161502
# 75%      547.321543
# max      725.584814
# Name: Yearly Amount Spent, dtype: float64

# %%
y_test.describe()
# Out:
# count    150.000000
# mean     500.692856
# std       85.483919
# min      256.670582
# 25%      444.869568
# 50%      504.424406
# 75%      553.731092
# max      765.518462
# Name: Yearly Amount Spent, dtype: float64

# %%
# Import LinearRegression from sklearn.linear_model 
from sklearn.linear_model import LinearRegression

# %%
# Create an instance of a LinearRegression() model to lm
lm = LinearRegression()

# %%
# Train/fit lm on the training data
lm.fit(X_train,y_train)
# Out:
# LinearRegression()

# %%
# Print out the coefficients of the model
coefficient= pd.DataFrame(lm.coef_,index=X_train.columns,columns=["Coeff"])
coefficient
# Out:
#                           Coeff
# Avg. Session Length   25.981550
# Time on App           38.590159
# Time on Website        0.190405
# Length of Membership  61.279097

# %%
# Use lm.predict() to predict off the x_test set of the data
predictions=lm.predict(x_test)
predictions
# Out:
# array([456.44186104, 402.72005312, 409.2531539 , 591.4310343 ,
#        590.01437275, 548.82396607, 577.59737969, 715.44428115,
#        473.7893446 , 545.9211364 , 337.8580314 , 500.38506697,
#        552.93478041, 409.6038964 , 765.52590754, 545.83973731,
#        693.25969124, 507.32416226, 573.10533175, 573.2076631 ,
#        397.44989709, 555.0985107 , 458.19868141, 482.66899911,
#        559.2655959 , 413.00946082, 532.25727408, 377.65464817,
#        535.0209653 , 447.80070905, 595.54339577, 667.14347072,
#        511.96042791, 573.30433971, 505.02260887, 565.30254655,
#        460.38785393, 449.74727868, 422.87193429, 456.55615271,
#        598.10493696, 449.64517443, 615.34948995, 511.88078685,
#        504.37568058, 515.95249276, 568.64597718, 551.61444684,
#        356.5552241 , 464.9759817 , 481.66007708, 534.2220025 ,
#        256.28674001, 505.30810714, 520.01844434, 315.0298707 ,
#        501.98080155, 387.03842642, 472.97419543, 432.8704675 ,
# ...

# %%
# Create a scatterplot of the real test values versus the predicted values
plt.scatter(x=predictions,y=y_test)
plt.xlabel("Y Test (True Values)")
plt.ylabel("Predicted Values")
plt.title("Predictes vs. True Values")
# Out:
# Text(0.5, 1.0, 'Predictes vs. True Values')

# %%
pred_ytest=pd.DataFrame([predictions,y_test],index=["Predictions","y_Test"]).T
pred_ytest
# Out:
#      Predictions      y_Test
# 0     456.441861  452.315675
# 1     402.720053  401.033135
# 2     409.253154  410.069611
# 3     591.431034  599.406092
# 4     590.014373  586.155870
# ..           ...         ...
# 145   478.300766  479.731938
# 146   484.410296  488.387526
# 147   457.590999  461.112248
# 148   411.526576  407.704548
# 149   375.479006  375.398455
#
# [150 rows x 2 columns]

# %%
sns.lmplot(x="Predictions",y="y_Test",data=pred_ytest)

# %% [markdown]
# # Evaluating the Model

# %%
# Calculate the mean absolute square, mean squared error, and root mean squared error
import sklearn.metrics

# %%
print("MAE: ",sklearn.metrics.mean_absolute_error(y_test,predictions))
# Out:
# MAE:  7.228148653430815

# %%
print("MSE: ",sklearn.metrics.mean_squared_error(y_test,predictions))
# Out:
# MSE:  79.81305165097429

# %%
print("RMSE: ",np.sqrt(sklearn.metrics.mean_squared_error(y_test,predictions)))
# Out:
# RMSE:  8.933815066978624

# %%
print("R^2: ",sklearn.metrics.explained_variance_score(y_test,predictions))
# Out:
# R^2:  0.9890771231889607

# %% [markdown]
# # Residuals

# %%
sns.distplot([y_test-predictions],bins=50)

# %%
plt.hist([y_test-predictions],density=True,bins=50)
# Out:
# (array([0.00585265, 0.        , 0.        , 0.        , 0.        ,
#         0.        , 0.00585265, 0.00585265, 0.01170529, 0.00585265,
#         0.00585265, 0.02341058, 0.01170529, 0.01170529, 0.03511587,
#         0.04096852, 0.03511587, 0.04096852, 0.04096852, 0.04096852,
#         0.05267381, 0.04682116, 0.03511587, 0.03511587, 0.04096852,
#         0.05267381, 0.01170529, 0.04096852, 0.03511587, 0.01755794,
#         0.04096852, 0.02926323, 0.02341058, 0.02926323, 0.02341058,
#         0.00585265, 0.        , 0.01170529, 0.00585265, 0.00585265,
#         0.00585265, 0.        , 0.        , 0.        , 0.        ,
#         0.        , 0.        , 0.        , 0.        , 0.00585265]),
#  array([-26.95573072, -25.81664466, -24.67755861, -23.53847256,
#         -22.3993865 , -21.26030045, -20.1212144 , -18.98212835,
#         -17.84304229, -16.70395624, -15.56487019, -14.42578414,
#         -13.28669808, -12.14761203, -11.00852598,  -9.86943992,
# ...
